# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

import pandas as pd
import scipy.io as sio
from keras.models import load_model
#from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# %%
    1.
    '
    m = m[25:m.shape[0]-25,25:m.shape[1]-25]
    m = cv2.medianBlur(m, 3)
    kernel = np.ones((2,2),np.uint8)
    m = cv2.erode(m,kernel,iterations = 3)
    m = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)
    m = cv2.bitwise_not(m)
    kernel = np.ones((2,2),np.uint8)
    m = cv2.erode(m,kernel,iterations = 3)
    m = cv2.medianBlur(m, 5)
    kernel = np.ones((2,2),np.uint8)
    m = cv2.dilate(m,kernel,iterations = 6)
    m =  cv2.resize(m , (150,150))
    
    2.
    
    m = m[25:m.shape[0]-25,25:m.shape[1]-25]
    m = cv2.medianBlur(m, 3)
    kernel = np.ones((2,2),np.uint8)
    m = cv2.erode(m,kernel,iterations = 3)
    m = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)
    m = cv2.bitwise_not(m)
    m =  cv2.resize(m , (150,150))

# %%
# kernel = np.ones((5,3),np.uint8)
# im = cv2.erode(imga,kernel,iterations = 1)

# kernel = np.ones((3,5),np.uint8)
# im = cv2.erode(im,kernel,iterations = 1)

# kernel = np.ones((7,7),np.uint8)
# im = cv2.dilate(im,kernel,iterations = 1)

# kernel = np.ones((7,7),np.uint8)
# im = cv2.medianBlur(im, 51)
# #im[im < 0] = 0
# im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# # kernel = np.ones((2,2),np.uint8)

# img = cv2.cvtColor(imga, cv2.COLOR_BGR2RGB)
# img[img > 0 ] = 255
# img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# img = cv2.bitwise_or(img,im)


# kernel = np.ones((1,3),np.uint8)
# img = cv2.erode(img,kernel,iterations = 1)

# kernel = np.ones((3,1),np.uint8)
# img = cv2.erode(img,kernel,iterations = 1)
# img = cv2.medianBlur(img, 3)

# img = cv2.bitwise_not(img)
# kernel = np.ones((2,2),np.uint8)
# img = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

# #img =  cv2.resize(img , (128,128))
# kernel = np.ones((2,2),np.uint8)
# img = cv2.dilate(img,kernel,iterations = 1)


# ########
# img1 = imga
# kernel = np.ones((5,3),np.uint8)
# im = cv2.erode(img1,kernel,iterations = 1)

# kernel = np.ones((3,5),np.uint8)
# im = cv2.erode(im,kernel,iterations = 1)

# kernel = np.ones((12,12),np.uint8)
# im = cv2.dilate(im,kernel,iterations = 1)

# kernel = np.ones((7,7),np.uint8)
# im = cv2.medianBlur(im, 51)
# im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# im[im >250]=255
# im[im <250]=0
# im = cv2.bitwise_not(im)
# print(type(im))
# #
# m = cv2.bitwise_and(img1 , img1, mask=im)
# m[m>5]=255

# m = cv2.medianBlur(m, 3)
# #
# kernel = np.ones((3,3),np.uint8)
# m = cv2.erode(m,kernel,iterations = 1)
# m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)
# m[m<250] = 0
# m = cv2.bitwise_not(m)

# kernel = np.ones((4,4),np.uint8)
# m = cv2.dilate(m,kernel,iterations = 1)

# kernel = np.ones((4,4),np.uint8)
# m = cv2.erode(m,kernel,iterations = 1)
# m = cv2.medianBlur(m, 7)

# kernel = np.ones((4,4),np.uint8)
# m = cv2.dilate(m,kernel,iterations = 1)

# kernel = np.ones((4,4),np.uint8)
# m = cv2.erode(m,kernel,iterations = 1)
# m = cv2.medianBlur(m, 7)

# kernel = np.ones((4,2),np.uint8)
# m = cv2.dilate(m,kernel,iterations = 1)

# kernel = np.ones((20,20),np.uint8)
# m = cv2.morphologyEx(m, cv2.MORPH_CLOSE, kernel)


# kernel = np.ones((3,3),np.uint8)
# m = cv2.erode(m,kernel,iterations = 1)
# m[m>5]=255
# m = cv2.medianBlur(m,5)
# kernel = np.ones((2,2),np.uint8)
# m = cv2.medianBlur(m,5)
# m = cv2.dilate(m,kernel,iterations = 1)
# # m = m[25:m.shape[0]-25,25:m.shape[1]-25]
# # m = cv2.medianBlur(m, 3)
# # kernel = np.ones((2,2),np.uint8)
# # m = cv2.erode(m,kernel,iterations = 3)
# # m = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)
# # m = cv2.bitwise_not(m)
# # kernel = np.ones((2,2),np.uint8)
# # m = cv2.erode(m,kernel,iterations = 3)
# # m = cv2.medianBlur(m, 3)
# # kernel = np.ones((3,3),np.uint8)
# # m = cv2.dilate(m,kernel,iterations = 1)
# # m = cv2.medianBlur(m, 5)
# # # 
# # kernel = np.ones((3,3),np.uint8)
# # m = cv2.dilate(m,kernel,iterations = 1)
# # m =  cv2.resize(m , (150,150))


# kernel = np.ones((5,3),np.uint8)
# im = cv2.erode(img,kernel,iterations = 1)

# kernel = np.ones((3,5),np.uint8)
# im = cv2.erode(im,kernel,iterations = 1)

# kernel = np.ones((12,12),np.uint8)
# im = cv2.dilate(im,kernel,iterations = 1)

# kernel = np.ones((7,7),np.uint8)
# im = cv2.medianBlur(im, 91)
# im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# im[im >250]=255
# im[im <250]=0
# im = cv2.bitwise_not(im)
# m = cv2.bitwise_and(img , img, mask=im)
# m[m>5]=255

# # m = cv2.medianBlur(m, 5)
# kernel = np.ones((3,3),np.uint8)
# m = cv2.erode(m,kernel,iterations = 1)
# m = cv2.medianBlur(m, 5)
# # m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)
# # m[m<250] = 0
# # m = cv2.bitwise_not(m)

# # kernel = np.ones((2,2),np.uint8)
# # m = cv2.dilate(m,kernel,iterations = 1)
# m =  cv2.resize(m , (150,150))

m = cv2.imread('data/training/training/6.png' , 1)
m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)

ret , m= cv2.threshold(m, 0, 1, cv2.THRESH_BINARY)
m = cv2.bitwise_not(m)
m = cv2.medianBlur(m, 3)
kernel = np.ones((3,3),np.uint8)
m = cv2.dilate(m,kernel,iterations = 1)
m = cv2.medianBlur(m, 3)
height = m.shape[0]
width = m.shape[1]
if(height<width):
    diff = int((width - height)/2)
    m1 = cv2.copyMakeBorder(m, diff,diff,0,0,cv2.BORDER_CONSTANT, value = 255)
elif(height>width):
    diff = int((height - width)/2)
    m1 = cv2.copyMakeBorder(m,0,0,diff,diff,cv2.BORDER_CONSTANT, value = 255)
else:
    m1 = m
m1 =  m1[60:m1.shape[0]-60,60:m1.shape[1]-60]  
kernel = np.ones((3,3),np.uint8)
m1 = cv2.dilate(m1,kernel,iterations = 1)

# m1 = Image.fromarray(m1)
# m1 = m1.resize((300,300), Image.ANTIALIAS)
# m1 = np.asarray(m1)
m =  cv2.resize(m , (150,150))
kernel = np.ones((2,2),np.uint8)
m = cv2.dilate(m,kernel,iterations = 1)

plt.figure(figsize=(6,10))
plt.imshow(m1 , cmap=plt.cm.binary)
m[m > 10] = 255


plt.show()
print(max(m1[1]))
# Out:
# 255

# %%
m = cv2.imread('data/training/training/7.png' , 1)
m
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img = cv2.imread('data/training/training/1400.png' , 1)

kernel = np.ones((5,3),np.uint8)
im = cv2.erode(img,kernel,iterations = 1)

kernel = np.ones((3,5),np.uint8)
im = cv2.erode(im,kernel,iterations = 1)

kernel = np.ones((7,7),np.uint8)
im = cv2.dilate(im,kernel,iterations = 1)

kernel = np.ones((7,7),np.uint8)
im = cv2.medianBlur(im, 51)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# im[im <10]=0
# im[im >=10] =255
print(im.shape)

m = cv2.bitwise_and(img , img, mask=im)
# plt.figure(figsize=(6,10))
# plt.imshow(m, cmap=plt.cm.binary)

# plt.show()
# Out:
# (591, 436)

# %%
data = pd.read_csv("data/training/solution.csv", index_col=0)
lable = np.asarray(data)
lable = lable-1
#im.shape

# %%
data_train = []
for i in range(1,5001):
    m = cv2.imread('data/training/training/'+str(i)+'.png' , 1)

#     kernel = np.ones((5,3),np.uint8)
#     im = cv2.erode(img,kernel,iterations = 1)

#     kernel = np.ones((3,5),np.uint8)
#     im = cv2.erode(im,kernel,iterations = 1)

#     kernel = np.ones((12,12),np.uint8)
#     im = cv2.dilate(im,kernel,iterations = 1)

#     
#     im = cv2.medianBlur(im, 51)
#     im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
#     im[im >250]=255
#     im[im <250]=0
#     im = cv2.bitwise_not(im)
#     m = cv2.bitwise_and(img , img, mask=im)
#     m[m>5]=255

#     m = cv2.medianBlur(m, 3)
#     kernel = np.ones((3,3),np.uint8)
#     m = cv2.erode(m,kernel,iterations = 1)
#     m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)
#     m[m<250] = 0
#     m = cv2.bitwise_not(m)
    
#     kernel = np.ones((4,4),np.uint8)
#     m = cv2.dilate(m,kernel,iterations = 1)
#     m[m>5]=255
#     m = m[25:m.shape[0]-25,25:m.shape[1]-25]
#     m = cv2.medianBlur(m, 3)
#     kernel = np.ones((2,2),np.uint8)
#     m = cv2.erode(m,kernel,iterations = 3)
#     m = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)
#     m = cv2.bitwise_not(m)
#     kernel = np.ones((2,2),np.uint8)
#     m = cv2.erode(m,kernel,iterations = 3)
#     m = cv2.medianBlur(m, 3)
#     kernel = np.ones((3,3),np.uint8)
#     m = cv2.dilate(m,kernel,iterations = 1)
#     m = cv2.medianBlur(m, 5)
#     # 
#     kernel = np.ones((3,3),np.uint8)
#     m = cv2.dilate(m,kernel,iterations = 1)
#     m =  cv2.resize(m , (150,150))
#     m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)

#     ret , m= cv2.threshold(m, 0, 1, cv2.THRESH_BINARY)
#     m = cv2.bitwise_not(m)
#     m = cv2.medianBlur(m, 3)
#     kernel = np.ones((3,3),np.uint8)
#     m = cv2.dilate(m,kernel,iterations = 1)
#     m = cv2.medianBlur(m, 3)
#     height = m.shape[0]
#     width = m.shape[1]
#     if(height<width):
#         diff = int((width - height)/2)
#         m1 = cv2.copyMakeBorder(m, diff,diff,0,0,cv2.BORDER_CONSTANT, value = 254)
#     elif(height>width):
#         diff = int((height - width)/2)
#         m1 = cv2.copyMakeBorder(m,0,0,diff,diff,cv2.BORDER_CONSTANT, value = 254)
#     else:
#         m1 = m
#     m1 =  m1[40:m1.shape[0]-40,40:m1.shape[1]-40]  
#     m1 =  cv2.resize(m1 , (150,150))

    m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)

    ret , m= cv2.threshold(m, 0, 1, cv2.THRESH_BINARY)
    m = cv2.bitwise_not(m)
    m = cv2.medianBlur(m, 3)
    kernel = np.ones((3,3),np.uint8)
    m = cv2.dilate(m,kernel,iterations = 1)
    m = cv2.medianBlur(m, 3)
    height = m.shape[0]
    width = m.shape[1]
    if(height<width):
        diff = int((width - height)/2)
        m1 = cv2.copyMakeBorder(m, diff,diff,0,0,cv2.BORDER_CONSTANT, value = 254)
    elif(height>width):
        diff = int((height - width)/2)
        m1 = cv2.copyMakeBorder(m,0,0,diff,diff,cv2.BORDER_CONSTANT, value = 254)
    else:
        m1 = m
    m1 =  m1[40:m1.shape[0]-40,40:m1.shape[1]-40]  
    kernel = np.ones((3,3),np.uint8)
    m1 = cv2.dilate(m1,kernel,iterations = 1)
    m1 = Image.fromarray(m1)
    m1 = m1.resize((150,150), Image.ANTIALIAS)
    m1 = np.array(m1)

    m1 = m1.reshape((150,150,1))
    if i%500 == 0:
        print("Check : " , i)
    
    data_train.append(m1)
    
data_t = np.asarray(data_train)
# Out:
# Check :  500
# Check :  1000
# Check :  1500
# Check :  2000
# Check :  2500
# Check :  3000
# Check :  3500
# Check :  4000
# Check :  4500
# Check :  5000

# %%
plt.figure(figsize=(16,20)) # width,height : (20,10) 
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(data_t[i].reshape((150,150)), cmap=plt.cm.binary)
    plt.xlabel("No.:" +str(lable[i]))
    plt.grid('off')

# %%
#data_t1 = sio.loadmat('data/load/data_b.mat')['data']
# data_t2 = sio.loadmat('data/load/data_low_noise.mat')['data']
data_t = sio.loadmat('data/load/data_wb.mat')['data']

X_train1 = data_t.reshape(5000,150,150,1)[0:4700]/255
y_train = lable[0:4700]

X_test1 = data_t.reshape(5000,150,150,1)[4700:5000] /255
y_test = lable[4700:5000]

# X_train2 = data_t2.reshape(5000,150,150,1)[0:4500]/255
# X_test2 = data_t2.reshape(5000,150,150,1)[4500:5000] /255

# X_train3 = data_t3.reshape(5000,150,150,1)[0:4800]/255
# X_test3 = data_t3.reshape(5000,150,150,1)[4800:5000] /255

# X_val = data_t.reshape(5000,150,150,1)[4500:5000] /255
# y_val = lable[4500:5000]

# train_m = X_train.mean(axis=0)
# train_s = X_train.std(axis=0)

# train_set = (X_train - train_m)/train_s
# test_set = (X_train - train_m)/train_s
# y_test.shape

# %%
X_train1.dtype
# Out:
# dtype('float64')

# %%
from keras.utils import to_categorical
# #one-hot encode target column
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

y_val = to_categorical(y_val)

y_train[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3b85eae5f921> in <module>()
#       1 from keras.utils import to_categorical
#       2 # #one-hot encode target column
# ----> 3 y_train = to_categorical(y_train)
#       4 y_test = to_categorical(y_test)
#       5
#
# NameError: name 'y_train' is not defined

# %%
#print(data_t.shape)
model = load_model('models/paniit_ic_98.67.h5')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_16 (Conv2D)           (None, 150, 150, 32)      320
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 148, 148, 32)      9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 74, 74, 64)        18496
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 36, 36, 64)        0
# ...

# %%
#create model
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(150,150,1)))
# model.add(Conv2D(32, (5, 5), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.2))
# model.add(Conv2D(64, (5, 5), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.2))
# model.add(Flatten())
# model.add(Dropout(0.35))
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.25))
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(16, activation='relu'))
# model.add(Dense(6, activation='softmax'))

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(150,150,1)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))

model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# epoch = range(0,3)
# for i in epoch:

model.fit(X_train1, y_train, epochs=1,verbose =10, validation_data=(X_test1, y_test),batch_size=128)
#model.fit(X_train2, y_train, epochs=5, validation_data=(X_test2, y_test))
# model.fit(X_train3, y_train, epochs=5, validation_data=(X_test3, y_test))
#     test_loss, test_acc1 = model.evaluate(X_test1, y_test)
#     test_loss, test_acc2 = model.evaluate(X_test2, y_test)
#     test_loss, test_acc3 = model.evaluate(X_test3, y_test)
#     print('Test accuracy 1:', test_acc1 ,'Test accuracy 2:', test_acc2,'Test accuracy 3:', test_acc3  )
# Out:
# Train on 4700 samples, validate on 300 samples
# Epoch 1/1

# %%
test_loss, test_acc = model.evaluate(X_test1, y_test)
print('Test accuracy:', test_acc)
predictions = model.predict(X_test1)
# Out:
# 300/300 [==============================] - 2s 7ms/step
# Test accuracy: 0.9866666666666667

# %%
del model

# %%
sio.savemat('data/load/data_wb_.mat', {"data":data_t})

# %%
data_pa = sio.loadmat('data/load/data_wb_e.mat')['data']

# %%
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.9259999995231628

# %%
plt.figure(figsize=(16,300)) # width,height : (20,10) 
for i in range(300):
    plt.subplot(75,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train1[i].reshape((150,150)), cmap=plt.cm.binary)
    label =plt.xlabel("No.:" +str(np.argmax(predictions[i])+1))
    if np.argmax(predictions[i]) == y_test[i]:
        label.set_color('green')
    else:
        label.set_color('red')
    plt.grid('off')

# %%
# m[m>5]=255

#     m = m[25:m.shape[0]-25,25:m.shape[1]-25]
#     m = cv2.medianBlur(m, 3)
#     kernel = np.ones((2,2),np.uint8)
#     m = cv2.erode(m,kernel,iterations = 3)
#     m = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)
#     m = cv2.bitwise_not(m)
#     m =  cv2.resize(m , (150,150))

data_pa = []
for i in range(1,40001):
    m = cv2.imread('./data/training/p/testing_40k/'+str(i)+'.png' , 1)
    #print(img)
#     kernel = np.ones((5,3),np.uint8)
#     im = cv2.erode(img,kernel,iterations = 1)

#     kernel = np.ones((3,5),np.uint8)
#     im = cv2.erode(im,kernel,iterations = 1)

#     kernel = np.ones((12,12),np.uint8)
#     im = cv2.dilate(im,kernel,iterations = 1)

#     kernel = np.ones((7,7),np.uint8)
#     im = cv2.medianBlur(im, 51)
#     im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
#     im[im >250]=255
#     im[im <250]=0
#     im = cv2.bitwise_not(im)
#     m = cv2.bitwise_and(img , img, mask=im)
#     m[m>5]=255

#     m = cv2.medianBlur(m, 3)
#     kernel = np.ones((3,3),np.uint8)
#     m = cv2.erode(m,kernel,iterations = 1)
#     m = cv2.cvtColor(m, cv2.COLOR_BGR2GRAY)
#     m[m<250] = 0
#     m = cv2.bitwise_not(m)
#     m = m[25:m.shape[0]-25,25:m.shape[1]-25]
#     m =  cv2.resize(m , (150,150))
    
#     m = m.reshape((150,150,1))
    m[m>5]=255

    m = m[25:m.shape[0]-25,25:m.shape[1]-25]
    m = cv2.medianBlur(m, 3)
    kernel = np.ones((2,2),np.uint8)
    m = cv2.erode(m,kernel,iterations = 3)
    m = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)
    m = cv2.bitwise_not(m)
    m =  cv2.resize(m , (150,150))
    if i%500 == 0:
        print("Check : " , i)
    
    data_pa.append(m)
    
data_pa = np.asarray(data_pa)
print(data_pa.shape)
# Out:
# Check :  500
# Check :  1000
# Check :  1500
# Check :  2000
# Check :  2500
# Check :  3000
# Check :  3500
# Check :  4000
# Check :  4500
# Check :  5000
# Check :  5500
# Check :  6000
# Check :  6500
# Check :  7000
# Check :  7500
# Check :  8000
# Check :  8500
# Check :  9000
# Check :  9500
# Check :  10000
# Check :  10500
# Check :  11000
# Check :  11500
# Check :  12000
# Check :  12500
# Check :  13000
# Check :  13500
# Check :  14000
# Check :  14500
# Check :  15000
# Check :  15500
# Check :  16000
# Check :  16500
# Check :  17000
# Check :  17500
# Check :  18000
# Check :  18500
# Check :  19000
# Check :  19500
# Check :  20000
# Check :  20500
# Check :  21000
# Check :  21500
# Check :  22000
# Check :  22500
# Check :  23000
# Check :  23500
# Check :  24000
# Check :  24500
# Check :  25000
# Check :  25500
# Check :  26000
# Check :  26500
# Check :  27000
# Check :  27500
# Check :  28000
# Check :  28500
# Check :  29000
# Check :  29500
# Check :  30000
# ...

# %%
#model2 = load_model('models/paniit_final_96.4.h5')
test_loss, test_acc = model.evaluate(X_test3, y_test)
print(test_acc)
# Out:
# 500/500 [==============================] - 1s 1ms/step
# 0.9040000009536743

# %%
#sio.savemat('data/load/data_wb_e.mat', {"data":data_pa})
#X_t = data_pa.reshape(40000,150,150,1)/255
predictions = model.predict(X_t)
# for i in range(20):
#     print(i+1,"-",np.argmax(predictions[i])+1)

# %%
plt.figure(figsize=(16,300)) # width,height : (20,10) 
for i in range(301):
    plt.subplot(25,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test1[i].reshape((150,150)), cmap=plt.cm.binary)
    label =plt.xlabel("No.:" +str(np.argmax(predictions[i])+1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7d49ea2f3e52> in <module>()
#       1 plt.figure(figsize=(16,300)) # width,height : (20,10)
#       2 for i in range(301):
# ----> 3     plt.subplot(25,4,i+1)
#       4     plt.xticks([])
#       5     plt.yticks([])
#
# D:\Program\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1042
#    1043     fig = gcf()
# -> 1044     a = fig.add_subplot(*args, **kwargs)
#    1045     bbox = a.bbox
#    1046     byebye = []
#
# D:\Program\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1018                     self._axstack.remove(ax)
#    1019
# -> 1020             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1021
#    1022         self._axstack.add(key, a)
#
# ...

# %%
#create model
model = Sequential()
model.add(Flatten(input_shape=(150, 150)))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(6, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train.reshape(4000,150,150), y_train, epochs=4)

# %%
test_loss, test_acc = model.evaluate(X_train.reshape(4000,150,150), y_train)
print(test_acc)

# %%
X_train[1]

# %%
model.save('models/paniit_ic_98.67.h5')

# %%
df = pd.DataFrame(np.argmax(predictions,axis=1)+1)#.shape
df.index += 1

# %%
df.head()
# Out:
#    0
# 1  3
# 2  6
# 3  5
# 4  2
# 5  1

# %%
df.to_csv("sol_to_up_98.67.csv")

# %%
import gc
gc.collect()
# Out:
# 1868

# %%
datagen = ImageDataGenerator(
        zoom_range=0.25, # randomly zoom into images
        rotation_range=40,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.25,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False
    
)  # randomly flip images
 
# Fit the model on the batches generated by datagen.flow().
batch_size = 128
history2 = model.fit_generator(datagen.flow(X_train1, y_train, batch_size=batch_size),
                              epochs=20,
                               verbose =1,
                              validation_data=(X_test1, y_test),
                              workers=4)
 
#model.evaluate(test_data, test_labels_one_hot)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 17s 473ms/step - loss: 0.3884 - acc: 0.8770 - val_loss: 0.0898 - val_acc: 0.9733
# Epoch 2/20
# 37/37 [==============================] - 17s 465ms/step - loss: 0.3877 - acc: 0.8749 - val_loss: 0.0822 - val_acc: 0.9733
# Epoch 3/20
# 37/37 [==============================] - 17s 460ms/step - loss: 0.3905 - acc: 0.8721 - val_loss: 0.1038 - val_acc: 0.9667
# Epoch 4/20
# 37/37 [==============================] - 17s 459ms/step - loss: 0.3956 - acc: 0.8724 - val_loss: 0.1066 - val_acc: 0.9600
# Epoch 5/20
# 37/37 [==============================] - 17s 462ms/step - loss: 0.3987 - acc: 0.8752 - val_loss: 0.0827 - val_acc: 0.9767
# Epoch 6/20
# 37/37 [==============================] - 17s 460ms/step - loss: 0.3878 - acc: 0.8786 - val_loss: 0.1122 - val_acc: 0.9700
# Epoch 7/20
# 37/37 [==============================] - 17s 463ms/step - loss: 0.3591 - acc: 0.8836 - val_loss: 0.0620 - val_acc: 0.9800
# Epoch 8/20
# ...

# %%
model.evaluate(X_test3, y_test)
# Out:
# 500/500 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 2ms/step
# [0.15093947154283524, 0.9439999995231628]
